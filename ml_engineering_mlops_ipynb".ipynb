# %% [markdown]
# <a href="https://colab.research.google.com/github/Katherina-B/Apache-Hive/blob/main/ml_engineering_mlops_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wandb -qU
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 20.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 22.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.6/289.6 kB 18.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.6 MB/s eta 0:00:00

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !cd /content; rm -rf lb5; git clone https://git_token@github.com/Katherina-B/lb5.git
# %cd /content/lb5
# Out:
# Cloning into 'lb5'...
# remote: Enumerating objects: 665, done.
# remote: Counting objects: 100% (154/154), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 665 (delta 96), reused 148 (delta 93), pack-reused 511
# Receiving objects: 100% (665/665), 227.82 KiB | 7.12 MiB/s, done.
# Resolving deltas: 100% (412/412), done.
# /content/lb5

# %%
# !pip install poetry
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.9/249.9 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.7/514.7 kB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.5/309.5 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 38.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 62.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 53.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: keyring
#     Found existing installation: keyring 23.5.0
#     Uninstalling keyring-23.5.0:
#       Successfully uninstalled keyring-23.5.0
# ...

# %%
# !poetry lock --no-update
# !poetry install --sync --verbose --with dev
# Out:
# Creating virtualenv lb5-NLPEsiyt-py3.10 in /root/.cache/pypoetry/virtualenvs
# Updating dependencies
# Resolving dependencies... (7.9s)Source (pytorch): Authorization error accessing https://download.pytorch.org/whl/cu118/dvc/
# Resolving dependencies... (15.0s)
#
# Writing lock file
# Using virtualenv: /root/.cache/pypoetry/virtualenvs/lb5-NLPEsiyt-py3.10
# Installing dependencies from lock file
#
# Finding the necessary packages for the current system
#
# Package operations: 123 installs, 1 update, 0 removals
#
#   - Installing frozenlist (1.4.1): Pending...
#   - Installing idna (3.7): Pending...
#   - Installing multidict (6.0.5): Pending...
#   - Installing pycparser (2.22): Pending...
#   - Installing vine (5.1.0): Pending...
#   - Installing wcwidth (0.2.13): Pending...
#   - Installing vine (5.1.0): Pending...
#   - Installing wcwidth (0.2.13): Pending...
#   - Installing pycparser (2.22): Downloading... 0%
#   - Installing vine (5.1.0): Pending...
# ...

# %%
# !source "$(poetry env info --path)/bin/activate"; python load_date.py
# Out:
# Archive extracted to /content/lb5/data/102flower
# ...
# 100% 344862509/344862509 [00:13<00:00, 25504668.95it/s]
# Extracting /content/lb5/data/102flower/jpg/flowers-102/102flowers.tgz to /content/lb5/data/102flower/jpg/flowers-102
# ...
# 100% 502/502 [00:00<00:00, 1944174.15it/s]
# ...
# 100% 14989/14989 [00:00<00:00, 44398603.57it/s]

# %%
# !source "$(poetry env info --path)/bin/activate"; python train.py
# Out:
# ...
# 100% 344862509/344862509 [00:10<00:00, 31779320.33it/s]
# Extracting /content/lb5/data/102flower/jpg/flowers-102/102flowers.tgz to /content/lb5/data/102flower/jpg/flowers-102
# ...
# 100% 502/502 [00:00<00:00, 2318877.32it/s]
# ...
# 100% 14989/14989 [00:00<00:00, 64020797.00it/s]
# /root/.cache/pypoetry/virtualenvs/lb5-NLPEsiyt-py3.10/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /root/.cache/pypoetry/virtualenvs/lb5-NLPEsiyt-py3.10/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
# !source "$(poetry env info --path)/bin/activate"; python interp.py
